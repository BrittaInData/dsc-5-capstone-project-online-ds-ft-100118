# %%
import pandas as pd

# %% [markdown]
# ...from http://insideairbnb.com/get-the-data.html

# %%
# CALENDAR data (only available detailed)
df = pd.read_csv('data/insideAirbnb/calendar.csv.gz', compression='gzip')
df.head()
# Out:
#    listing_id        date available price
# 0        2015  2019-09-10         f   NaN
# 1        2015  2019-09-09         f   NaN
# 2        2015  2019-09-08         f   NaN
# 3        2015  2019-09-07         f   NaN
# 4        2015  2019-09-06         f   NaN

# %%
df.available.unique()
# Out:
# array(['f', 't'], dtype=object)

# %%
df.shape
# Out:
# (8231480, 4)

# %%
df.groupby(['listing_id']).count().head()
# Out:
#             date  available  price
# listing_id
# 2015         365        365    141
# 2695         365        365      0
# 3176         365        365    220
# 3309         365        365    297
# 7071         365        365     26

# %%
df.date.min()
# Out:
# '2018-11-07'

# %%
# detailed LISTINGS data
df = pd.read_csv('data/airbnb_Berlin/listings.csv.gz', compression='gzip')
print(df.shape)
df.head(3)
# Out:
# (22552, 96)
#      id                        listing_url       scrape_id last_scraped  \
# 0  2015  https://www.airbnb.com/rooms/2015  20181107122246   2018-11-07
# 1  2695  https://www.airbnb.com/rooms/2695  20181107122246   2018-11-07
# 2  3176  https://www.airbnb.com/rooms/3176  20181107122246   2018-11-07
#
#                                                name  \
# 0  Berlin-Mitte Value! Quiet courtyard/very central
# 1                Prenzlauer Berg close to Mauerpark
# 2                   Fabulous Flat in great Location
#
#                                              summary  \
# 0  Great location!  30 of 75 sq meters. This wood...
# 1                                                NaN
# 2  This beautiful first floor apartment  is situa...
#
#                                                space  \
# 0  A+++ location! This „Einliegerwohnung“ is an e...
# 1  In the summertime we are spending most of our ...
# 2  1st floor (68m2) apartment on Kollwitzplatz/ P...
#
# ...

# %%
# summary information and metrics for LISTINGS
df = pd.read_csv('data/airbnb_Berlin/listings.csv')
print(df.shape)
df.head(3)
# Out:
# (22552, 16)
#      id                                              name  host_id host_name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central     2217       Ian
# 1  2695                Prenzlauer Berg close to Mauerpark     2986   Michael
# 2  3176                   Fabulous Flat in great Location     3718    Britta
#
#   neighbourhood_group             neighbourhood   latitude  longitude  \
# 0               Mitte           Brunnenstr. Süd  52.534537  13.402557
# 1              Pankow  Prenzlauer Berg Nordwest  52.548513  13.404553
# 2              Pankow   Prenzlauer Berg Südwest  52.534996  13.417579
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt     60               4                118  2018-10-28
# 1     Private room     17               2                  6  2018-10-01
# 2  Entire home/apt     90              62                143  2017-03-20
#
# ...

# %%
# detailed REVIEW data and listing ID 
df = pd.read_csv('data/airbnb_Berlin/reviews.csv.gz', compression='gzip')
print(df.shape)
df.head(3)
# Out:
# (401963, 6)
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0        2015  69544350  2016-04-11      7178145         Rahel
# 1        2015  69990732  2016-04-15     41944715        Hannah
# 2        2015  71605267  2016-04-26     30048708        Victor
#
#                                             comments
# 0  Mein Freund und ich hatten gute gemütliche vie...
# 1  Jan was very friendly and welcoming host! The ...
# 2  Un appartement tres bien situé dans un quartie...

# %%
# summary REVIEW data and listing ID 
df = pd.read_csv('data/airbnb_Berlin/reviews.csv')
print(df.shape)
df.head(3)
# --> useless
# Out:
# (401963, 2)
#    listing_id        date
# 0        2015  2016-04-11
# 1        2015  2016-04-15
# 2        2015  2016-04-26

# %%
# NEIGHBOURHOOD ist for geo filter (only available in one version)
df = pd.read_csv('data/airbnb_Berlin/neighbourhoods.csv')
print(df.shape)
df.head(3)
# Out:
# (139, 2)
#     neighbourhood_group        neighbourhood
# 0  Charlottenburg-Wilm.            Barstraße
# 1  Charlottenburg-Wilm.  Charlottenburg Nord
# 2  Charlottenburg-Wilm.  Düsseldorfer Straße

# %% [markdown]
# ... from http://tomslee.net/airbnb-data-collection-get-the-data

# %%
# first dataset
df = pd.read_csv('data/airbnb_Berlin/tomslee/tomslee_airbnb_berlin_0017_2014-05-18.csv')
print(df.shape)
df.head(3)
# Out:
# (7789, 14)
#    room_id  host_id        room_type  borough              neighborhood  \
# 0     1944     2164     Private room      NaN                     Mitte
# 1     3176     3718  Entire home/apt      NaN                    Pankow
# 2     6083    11892  Entire home/apt      NaN  Friedrichshain-Kreuzberg
#
#    reviews  overall_satisfaction  accommodates  bedrooms  price  minstay  \
# 0        4                   4.5             2       1.0   41.0        1
# 1       57                   5.0             4       1.0  107.0        2
# 2       32                   5.0             4       NaN   98.0        3
#
#     latitude  longitude            last_modified
# 0  52.544251  13.397491  2014-05-19 07:34:14.697
# 1  52.534240  13.418094  2014-05-19 00:01:50.741
# 2  52.503725  13.453809  2014-05-19 08:39:20.351

# %%
# last dataset
df = pd.read_csv('data/airbnb_Berlin/tomslee/tomslee_airbnb_berlin_1471_2017-07-21.csv')
print(df.shape)
df.head(3)
# Out:
# (21864, 20)
#     room_id  survey_id   host_id    room_type  country    city  borough  \
# 0   7935870       1471  41848444  Shared room      NaN  Berlin      NaN
# 1  18339755       1471   2310164  Shared room      NaN  Berlin      NaN
# 2   8135806       1471  21857190  Shared room      NaN  Berlin      NaN
#
#                  neighborhood  reviews  overall_satisfaction  accommodates  \
# 0                       Mitte        0                   0.0             3
# 1  Charlottenburg-Wilmersdorf        0                   0.0             2
# 2  Charlottenburg-Wilmersdorf        0                   0.0             1
#
#    bedrooms  bathrooms  price  minstay  \
# 0       1.0        NaN   71.0      NaN
# 1       1.0        NaN   70.0      NaN
# 2       1.0        NaN   72.0      NaN
#
#                                        name               last_modified  \
# 0                  Moabiter Schlummermutter  2017-07-25 07:33:11.130011
# ...
